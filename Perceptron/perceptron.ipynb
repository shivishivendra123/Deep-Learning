# %%
import pandas as pd
from sklearn.linear_model import Perceptron

# %%
df = pd.read_csv('/Users/shivendragupta/Desktop/Deep Learning/Perceptron/placement.csv')
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
import matplotlib.pyplot as plt
plt.scatter(df['cgpa'],df['resume_score'],c=df['placed'])

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
p = Perceptron()
p.fit(X,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[ 40.26, -36.  ]])

# %%
p.intercept_
# Out:
# array([-25.])
